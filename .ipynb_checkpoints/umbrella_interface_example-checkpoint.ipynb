# %%
from oxDNA_analysis_tools.UTILS.oxview import from_path
import oxpy
from oxdna_json_utils import input_json
from simulation_interfaces import *
from forces import Force
from production_files import write_production, get_windows_per_gpu, run_production_slurm_files
from analysis import wham_analysis
from sim_macros import *
from copy import deepcopy

# %% [markdown]
# ### oxView Interactive Conf Visulization

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/1p_systems'
systems = ['1p_k1_max8', '1p_k5_max8', '1p_k20_max8', '1p_k5_max6']

# %%
dat = f"//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment/a4b8.dat"
top = f"//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment/a4b8.top"
from_path(dat, top, Inbox=['None', 'Origin'])
# Out:
# <script>function handle(){let t_files = [];let t_ext = [];t_files.push(new Blob(['t = 0\nb = 20 20 20\nE = 0 0 0\n-0.15555572509765625 2.6792449951171875 -0.3824939727783203 0.3890617730039575 0.39627156564026966 0.8316247850154697 -0.8907562945302239 -0.06837834997724004 0.44930794006914165 0 0 0 0 0 0\n-0.48421478271484375 2.382284164428711 0.047069549560546875 0.3500079331997758 0.861186790109429 0.3685807363906034 -0.8916115978946574 0.18560788989476543 0.4130114643790758 0 0 0 0 0 0\n-0.851104736328125 2.408893585205078 0.393646240234375 0.3321169798690225 0.9421202660672199 0.04590986765511772 -0.7626716118704375 0.23958152622301968 0.6007767511643551 0 0 0 0 0 0\n-0.9166297912597656 2.527111053466797 0.8923988342285156 -0.18498411916071644 0.828170382425974 -0.5290696488466807 -0.8776040067134973 0.10306452723178561 0.46817615341546887 0 0 0 0 0 0\n-1.2557621002197266 2.7490386962890625 1.1991729736328125 -0.3249025074802701 0.3352021892413894 -0.8843516568429173 -0.893045491020378 0.19905166272777983 0.40354452856342665 0 0 0 0 0 0\n-1.6253070831298828 3.1820240020751953 1.3375205993652344 -0.29889622243297725 -0.4000668931309413 -0.8663760899493085 -0.9476283846862391 0.01738129596027744 0.31890176400843323 0 0 0 0 0 0\n-2.149951934814453 3.3178138732910156 1.4331207275390625 -0.05064489615766595 -0.6927970024241866 -0.7193520750823207 -0.9914114271366393 -0.05208461597376014 0.11996072241262273 0 0 0 0 0 0\n-2.565389633178711 3.4018936157226562 1.1804542541503906 0.03347399821241507 -0.9866198712439587 0.15956415985499223 -0.97298106724652 0.00432277219399167 0.2308444420391834 0 0 0 0 0 0\n-3.0111865997314453 3.2197647094726562 1.0395565032958984 0.2616309098994995 -0.5945012634437195 0.7603403940005959 -0.9651596439962873 -0.15787386423436137 0.208668887457308 0 0 0 0 0 0\n-3.369537353515625 2.786640167236328 1.1206493377685547 0.11712083253237297 0.2649166229541994 0.9571321191295727 -0.9931101269046351 0.034998850086345706 0.11183629255341655 0 0 0 0 0 0\n-2.8507080078125 3.7684059143066406 0.05397987365722656 -0.1362706626528723 0.8965644483162226 0.42142911208834954 0.816199952287593 -0.13949028263965868 0.5606782490295472 0 0 0 0 0 0\n-2.420705795288086 3.948688507080078 0.11956977844238281 -0.4036707996476245 0.37429766453812996 0.8348359981655972 0.8936966859842247 -0.03401103305599387 0.44738069146005677 0 0 0 0 0 0\n-2.091552734375 4.1815643310546875 0.4010467529296875 -0.4124835954641767 -0.580516396497217 0.7020384582562633 0.8929237557805342 -0.10503662489984192 0.43778359242031334 0 0 0 0 0 0\n-1.0288715362548828 3.610475540161133 0.3339672088623047 0.04447924806317957 -0.8952926863849063 0.44325230083715517 0.883982737045608 -0.17142636232333439 -0.4349569207472673 0 0 0 0 0 0\n-0.504974365234375 3.565126419067383 0.41423988342285156 -0.21412899210314437 -0.9728883474326915 0.0873901491621237 0.9641976361814264 -0.22484537757895262 -0.14059685118639093 0 0 0 0 0 0\n-0.07151412963867188 3.380167007446289 0.5622711181640625 -0.34960297626077413 -0.834475224730799 -0.4259446657725517 0.933034257628107 -0.3513459358620939 -0.07747972280253174 0 0 0 0 0 0\n0.31598854064941406 3.073383331298828 0.6528091430664062 -0.4160169182242889 -0.32471683302467336 -0.8494050283001576 0.8480661297463711 -0.47565834514597505 -0.23352297161093968 0 0 0 0 0 0\n0.6571197509765625 2.599752426147461 0.5373630523681641 -0.09557729974720888 0.3943350396375314 -0.9139829627991424 0.8129381531689661 -0.49895927356750885 -0.3002852018385432 0 0 0 0 0 0\n0.9645404815673828 2.2917652130126953 0.269500732421875 0.2815148712039354 0.9230080982430736 -0.2623078875457923 0.87056060414611 -0.36064980527471024 -0.334747595158014 0 0 0 0 0 0\n0.13646507263183594 1.8388652801513672 0.11723899841308594 -0.8291195591146031 -0.17160413099578636 -0.5320834322912031 0.5586263825262249 -0.29225482115661044 -0.7762239910337619 0 0 0 0 0 0\n-0.31149864196777344 1.9072494506835938 0.9604301452636719 -0.12202769305494195 -0.9903311901645784 0.065980 ...

# %% [markdown]
# ### Prepare 4 Systems for Umbrella Sampling Production

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment'
systems = ["k5_46_70", "k20_46_70", "k40_46_70"]

# %%
input_json_dict = input_json()
input_json_dict['steps'] = '2e5'
input_json_dict["CUDA_list"] = "no"
input_json_dict["use_average_seq"] = "false"
input_json_dict["seq_dep_file"] = 'oxDNA2_sequence_dependent_parameters.txt'
input_json_dict['print_conf_interval'] = '100000'
input_json_dict['print_energy_every'] = '100000'
prepare_umbrella_input = deepcopy(input_json_dict)

walker_com_forces = {}
k_values = ['5', '20', '40']
for walker, k in enumerate(k_values):
    walker_com_forces[str(walker)] = []
    walker_com_forces[str(walker)].append(Force.com_force(
        p1=get_op_string(46, 47),
        p2=get_op_string(70, 71),
        k=k,
        r0='0',
        pbc='0',
        rate='0'
    ))

walker_steps_per_conf = [1e5, 1e5, 1e5]
xmin = [0.2, 0.2, 0.2]
xmax = [7, 7, 7]
n_windows = [200, 200, 200]
processes = multi_prepare_melting_umbrella(path, systems, prepare_umbrella_input, walker_com_forces, walker_steps_per_conf, xmin, xmax, n_windows, n_walkers=3)
# Out:
# Running //scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment/k20_46_70/k20_46_70_eq
# Running //scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment/k40_46_70/k40_46_70_eq
# Running //scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment/k5_46_70/k5_46_70_eq
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
# INFO: seeding the RNG with -49727615
# INFO: Initializing backend
# INFO: Simulation type: MD
# INFO: CUDA backend precision: mixed
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: Converting temperature from Celsius (25.000000 C°) to simulation units (0.099383)
# INFO: Running Debye-Huckel at salt concentration =  1
# INFO: Using different widths for major and minor grooves
# INFO: Temperature change detected (new temperature: 25.00 C, 298.15 K), re-initialising the DNA interaction
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: seeding the RNG with 427541711
# INFO: Initializing backend
# INFO: Simulation type: MD
# INFO: CUDA backend precision: mixed
# INFO: seeding the RNG with -700402
# INFO: Initializing backend
# INFO: Setting the maximum IO limit to 5 MB/s
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Simulation type: MD
# INFO: CUDA backend precision: mixed
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: Converting temperature from Celsius (25.000000 C°) to simulation units (0.099383)
# INFO: Running Debye-Huckel at salt concentration =  1
# INFO: Using different widths for major and minor grooves
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: Converting temperature from Celsius (25.000000 C°) to simulation units (0.099383)
# INFO: Running Debye-Huckel at salt concentration =  1
# INFO: INFO: Using different widths for major and minor grooves
# Temperature change detected (new temperature: 25.00 C, 298.15 K), re-initialising the DNA interaction
# INFO: Using CUDA device 0
# INFO: Temperature change detected (new temperature: 25.00 C, 298.15 K), re-initialising the DNA interaction
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: pid: 2228150
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: (Cells.cpp) N_cells_side: 6, 6, 6; rcut=2.98518, IS_MC: 0
# INFO: N: 95, N molecules: 2
# INFO: Using randomly distributed velocities
# INFO: Initial kinetic energy: 30.235009
# INFO: Setting the maximum IO limit to 5 MB/s
# INFO: Setting the maximum IO limit to 5 MB/s
# INFO: Using CUDA device 1
# INFO: Using CUDA device 2
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: pid: 2228152
# INFO: pid: 2228155
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: (Cells.cpp) N_cells_side: 6, 6, 6; rcut=2.98518, IS_MC: 0
# INFO: N: 95, N molecules: 2
# INFO: Using randomly distributed velocities
# INFO: Initial kinetic energy: 25.480544
# INFO: (Cells.cpp) N_cells_side: 6, 6, 6; rcut=2.98518, IS_MC: 0
# INFO: N: 95, N molecules: 2
# INFO: Using randomly distributed velocities
# INFO: Initial kinetic energy: 27.247166

# %% [markdown]
# ### Run Time Visulization of Simulation Energies

# %%
input_json_dict = input_json()
input_json_dict['steps'] = '2e7'
prepare_umbrella_input = deepcopy(input_json_dict)
for i in systems:
    print(i)
    sim_path = f"{path}/{i}/{i}_pull"
    plot_energy(sim_path, prepare_umbrella_input)
# Out:
# k5_46_70
# k20_46_70
# k40_46_70

# %% [markdown]
# ### Create Umbrella Simulations for Production

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment'
systems = ["k5_46_70", "k20_46_70", "k40_46_70"]

# %%
input_json_dict = input_json()
input_json_dict['steps'] = '1e6'
input_json_dict["CUDA_list"] = "no"
input_json_dict["use_average_seq"] = "false"
input_json_dict["seq_dep_file"] = 'oxDNA2_sequence_dependent_parameters.txt'
input_json_dict['print_conf_interval'] = '100000'
input_json_dict['print_energy_every'] = '100000'
json_production = deepcopy(input_json_dict)

walker_com_forces = {}
k_values = ['5', '20', '40']
for walker, k in enumerate(k_values):
    walker_com_forces[str(walker)] = []
    walker_com_forces[str(walker)].append(Force.com_force(
        p1=get_op_string(46, 47),
        p2=get_op_string(70, 71),
        k=k,
        r0='0',
        pbc='0',
        rate='0'
    ))

xmin = [0.2, 0.2, 0.2]
xmax = [7, 7, 7]
n_windows = [200, 200, 200]
n_gpus = [2, 2, 2]
p1=get_op_string(46, 47)
p2=get_op_string(70, 71)
run_file = f'{path}/{systems[0]}/run.sh'
processes = multi_production_setup(path, systems, p1, p2, json_production,  walker_com_forces, xmin, xmax, n_gpus, run_file, n_walkers=3)
# Out:
# Writing production files...
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# ...
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
# 200 umbrella windows created
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)

# %% [markdown]
# ### Submit Slurm Files to Run Umbrella Sampling On Cluster

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment'
systems = ["k5_46_70", "k20_46_70", "k40_46_70"]

# %%
for system in systems:
    sim_dir = f"{path}/{system}/umbrella_production_1e6"
    windows_per_gpu = get_windows_per_gpu(2, 200)
    run_dirs = [0]
    for gpu_set in windows_per_gpu:
        run_dirs.append(run_dirs[-1] + gpu_set)
    run_dirs.pop()
    for i in run_dirs:
        os.chdir(os.path.join(f"{sim_dir}", str(i)))
        os.system("sbatch run.sh")
# Out:
# Submitted batch job 5416
# Submitted batch job 5417
# Submitted batch job 5418
# Submitted batch job 5419
# Submitted batch job 5420
# Submitted batch job 5421

# %%
n_gpus = 3
n_window = 100
for system in systems:
    sim_dir = f"{path}/{system}/umbrella_production_1e5"
    run_production_slurm_files(n_gpus, n_windows, sim_dir)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       3 n_window = 100
#       4 sim_dir = f"{path}/{system}/umbrella_production_1e5"
# ----> 5 run_production_slurm_files(n_gpus, n_windows, sim_dir)
#
# File /scratch/matthew/melting_sims/umbrella/gen_umbrella/production_files.py:184, in run_production_slurm_files(n_gpus, n_windows, sim_dir)
#     183 def run_production_slurm_files(n_gpus, n_windows, sim_dir):
# --> 184     windows_per_gpu = get_windows_per_gpu(n_gpus, n_windows)
#     185     run_dirs = [0]
#     186     for gpu_set in windows_per_gpu:
#
# File /scratch/matthew/melting_sims/umbrella/gen_umbrella/production_files.py:60, in get_windows_per_gpu(n_gpus, n_confs)
#      54 def get_windows_per_gpu(n_gpus, n_confs):
#      55     """
#      56     Calculate the optimal number of windows per gpu
#      57     :param n_gpus:
#      58     :return:
#      59     """
# ---> 60     round = n_confs // n_gpus
#      61     remainder = n_confs % n_gpus
#      62     w_p_gpu = []
#
# TypeError: unsupported operand type(s) for //: 'list' and 'int'

# %% [markdown]
# ### Preform WHAM analysis of Umbrella Sampling Simulation

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment'
systems = ["k5_46_70", "k20_46_70", "k40_46_70"]

# %%
wham_dir = "/home/matthew/software/wham/wham"
sim_dirs = [f"{path}/{system}/umbrella_production_1e6" for system in systems]
com_dir = [os.path.join(sim_dir, 'com_files') for sim_dir in sim_dirs]
xmin = ['0.2', '0.2', '0.2']
xmax = ['7', '7', '7']
k_values = ['5', '20', '40']
n_bins = ['400', '400', '400']
tol = ['1e-7', '1e-7', '1e-7']
n_boot = ['0', '0', '0']
temp = [str( (25 + 273.15) / 3000), str( (25 + 273.15) / 3000), str( (25 + 273.15) / 3000)]

multi_analysis(wham_dir, sim_dirs, com_dir, xmin, xmax, k_values, n_bins, tol, n_boot, temp, n_walkers=3)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# {'0': <Process name='Process-1' pid=2453808 parent=2453473 stopped exitcode=0>,
#  '1': <Process name='Process-2' pid=2453837 parent=2453473 stopped exitcode=0>,
#  '2': <Process name='Process-3' pid=2453903 parent=2453473 stopped exitcode=0>}

# %%
#Parameters for WHAM analysis
wham_dir = "/home/matthew/software/wham/wham"
sim_dir = f"{path}/k5_64_46/umbrella_production_1e5"
com_dir = os.path.join(sim_dir, 'com_files')
xmin = "0"
xmax = "7"
k = "5"
n_bins = '100'
tol = '1e-7'
n_boot = '0'
temp = str( (25 + 273.15) / 3000)

wham_analysis(wham_dir, sim_dir, com_dir, xmin, xmax, k, n_bins, tol, n_boot, temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 #Parameters for WHAM analysis
#       2 wham_dir = "/home/matthew/software/wham/wham"
# ----> 3 sim_dir = f"{path}/k5_64_46/umbrella_production_1e5"
#       4 com_dir = os.path.join(sim_dir, 'com_files')
#       5 xmin = "0"
#
# NameError: name 'path' is not defined

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/strand_displacment'
systems = ["k5_46_70", "k20_46_70", "k40_46_70"]

# %%
sim_dirs = [f"{path}/{system}/umbrella_production_1e6" for system in systems]
n_bins = ['400', '400', '400']
temps = [25, 25, 25]
c = ['tab:blue', 'tab:red', 'tab:green']
label = deepcopy(systems)
plot_free_energy(sim_dirs, n_bins, temps, seperate=False, c=c, label=label)

# %%
#Plot free energy
os.chdir(os.path.join(com_dir, 'time_series'))
freefile = pd.read_csv('freefile', sep='\t', nrows=int(n_bins))
plt_fig('Strand Displacement Reaction', 'COM Distance (nm)',
        'Free Energy (dG/kT)')
plt_err(freefile, 'tab:blue', 'k = 25', 25)

# %%
path = '//scratch/matthew/melting_sims/umbrella/sim_macros/1p_systems'
system =  '1p_k10_max7'
p1 = get_op_string(0, 8)
p2 = get_op_string(9, 17)
input_json_dict = input_json()
input_json_dict['steps'] = '1e5'
input_json_dict["CUDA_list"] = "no"
input_json_dict["use_average_seq"] = "false"
input_json_dict["seq_dep_file"] = 'oxDNA2_sequence_dependent_parameters.txt'
input_json_dict['print_conf_interval'] = '100000'
input_json_dict['print_energy_every'] = '100000'
input_umbrella = deepcopy(input_json_dict)

com_force_params = Force.com_force(
    p1=get_op_string(0, 8),
    p2=get_op_string(9, 17),
    k='10',
    r0='0',
    pbc='0',
    rate='0'
)
all_forces = [com_force_params]
steps_per_conf = 1e4
xmin = 0
xmax = 7
n_windows = 100
n_gpus = 5
run_file = f'{path}/{system}/run.sh'
#sim_dir = f"{path}/{system}/umbrella_production_1e5_example"
prepare_umbrella_sampling(path, system, p1, p2, input_umbrella, all_forces, steps_per_conf, xmin, xmax, n_windows, n_gpus, run_file)
# Out:
# Running //scratch/matthew/melting_sims/umbrella/sim_macros/1p_systems/1p_k10_max7/1p_k10_max7_eq
# Running //scratch/matthew/melting_sims/umbrella/sim_macros/1p_systems/1p_k10_max7/1p_k10_max7_r0_eq
# Running //scratch/matthew/melting_sims/umbrella/sim_macros/1p_systems/1p_k10_max7/1p_k10_max7_pull
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
# INFO: seeding the RNG with -1657879413
# INFO: Initializing backend
# INFO: Simulation type: MD
# INFO: CUDA backend precision: mixed
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: Converting temperature from Celsius (25.000000 C°) to simulation units (0.099383)
# INFO: Running Debye-Huckel at salt concentration =  1
# INFO: Using different widths for major and minor grooves
# INFO: Temperature change detected (new temperature: 25.00 C, 298.15 K), re-initialising the DNA interaction
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: Setting the maximum IO limit to 5 MB/s
# INFO: CUDA device not specified
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: pid: 2455771
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: (Cells.cpp) N_cells_side: 4, 4, 4; rcut=2.98518, IS_MC: 0
# INFO: N: 18, N molecules: 2
# INFO: Using randomly distributed velocities
# INFO: Initial kinetic energy: 5.246698
# INFO: Choosing device automatically
# cudaGetDeviceCount FAILED, CUDA Driver and Runtime CUDA Driver and Runtime version may be mismatched, exiting.
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
# INFO: seeding the RNG with 1767629857
# INFO: Initializing backend
# INFO: Simulation type: MD
# INFO: CUDA backend precision: mixed
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: Converting temperature from Celsius (25.000000 C°) to simulation units (0.099383)
# INFO: Running Debye-Huckel at salt concentration =  1
# INFO: Using different widths for major and minor grooves
# INFO: Temperature change detected (new temperature: 25.00 C, 298.15 K), re-initialising the DNA interaction
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: Setting the maximum IO limit to 5 MB/s
# INFO: CUDA device not specified
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: pid: 2455777
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: Parsing JSON force file forces.json
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 0
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 1
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 2
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 3
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 4
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 5
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 6
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 7
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 8
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 9
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 10
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 11
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 12
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 13
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 14
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 15
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 16
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000000 on particle 17
# INFO:    Force file parsed
# INFO: (Cells.cpp) N_cells_side: 4, 4, 4; rcut=2.98518, IS_MC: 0
# INFO: N: 18, N molecules: 2
# INFO: Using randomly distributed velocities
# INFO: Initial kinetic energy: 5.373150
# INFO: Choosing device automatically
# cudaGetDeviceCount FAILED, CUDA Driver and Runtime CUDA Driver and Runtime version may be mismatched, exiting.
#
# Please cite these publications for any work that uses the oxDNA simulation package
# 		- for the code:
# 			* P. Šulc et al., J. Chem. Phys. 137, 135101 (2012)
# 			* L. Rovigatti et al., J. Comput. Chem. 36, 1 (2015)
# 		- for the oxDNA model:
# 			* T. E. Ouldridge et al., J. Chem. Phys, 134, 085101 (2011)
# 		- for the oxDNA2 model:
# 			* B. E. K. Snodin et al., J. Chem. Phys. 142, 234901 (2015)
# 		- for the oxRNA model:
# 			* P. Šulc et al., J. Chem. Phys. 140, 235102 (2014)
# INFO: seeding the RNG with 469452831
# INFO: Initializing backend
# INFO: Simulation type: MD
# INFO: CUDA backend precision: mixed
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: Converting temperature from Celsius (25.000000 C°) to simulation units (0.099383)
# INFO: Running Debye-Huckel at salt concentration =  1
# INFO: Using different widths for major and minor grooves
# INFO: Temperature change detected (new temperature: 25.00 C, 298.15 K), re-initialising the DNA interaction
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: Setting the maximum IO limit to 5 MB/s
# INFO: CUDA device not specified
# INFO: The generator will try to take into account bonded interactions by choosing distances between bonded neighbours no larger than 2.000000
# INFO: Using 'oxDNA2_sequence_dependent_parameters.txt' as the input for sequence-dependent values
# INFO: pid: 2455782
# DEBUG: Debye-Huckel parameters: Q=0.054300, lambda_0=0.361646, lambda=0.360529, r_high=1.081586, cutoff=2.585176
# DEBUG: Debye-Huckel parameters: debye_huckel_RC=1.622379e+00, debye_huckel_B=8.546594e-03
# INFO: The Debye length at this temperature and salt concentration is 0.360529
# INFO: Parsing JSON force file forces.json
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 0
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 1
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 2
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 3
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 4
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 5
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 6
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 7
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 8
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 9
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 10
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 11
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 12
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 13
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 14
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 15
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 16
# INFO: Adding a COM force of stiffness = 10.000000, r0 = 0.000000, rate = 0.000007 on particle 17
# INFO:    Force file parsed
# INFO: (Cells.cpp) N_cells_side: 4, 4, 4; rcut=2.98518, IS_MC: 0
# INFO: N: 18, N molecules: 2
# INFO: Using randomly distributed velocities
# INFO: Initial kinetic energy: 5.428041
# INFO: Choosing device automatically
# cudaGetDeviceCount FAILED, CUDA Driver and Runtime CUDA Driver and Runtime version may be mismatched, exiting.
# Writing production files...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 30>()
#      28 run_file = f'{path}/{system}/run.sh'
#      29 #sim_dir = f"{path}/{system}/umbrella_production_1e5_example"
# ---> 30 prepare_umbrella_sampling(path, system, p1, p2, input_umbrella, all_forces, steps_per_conf, xmin, xmax, n_windows, n_gpus, run_file)
#
# File /scratch/matthew/melting_sims/umbrella/gen_umbrella/sim_macros.py:162, in prepare_umbrella_sampling(path, system, p1, p2, input_json_dict, all_forces, steps_per_conf, xmin, xmax, n_windows, n_gpus, run_file)
#     160 setup = spawn(prepare_melting_umbrella,(path, system, input_json_dict, all_forces, steps_per_conf, xmin, xmax, n_windows))
#     161 setup.join()
# --> 162 production_setup(path, system, p1, p2, input_json_dict, all_forces, xmin, xmax, n_gpus, run_file)
#
# File /scratch/matthew/melting_sims/umbrella/gen_umbrella/sim_macros.py:136, in production_setup(path, system, p1, p2, input_json_dict, all_forces, xmin, xmax, n_gpus, run_file)
#     134 input_json_dict["observables_file"] = "observables.json"
#     135 input_production = deepcopy(input_json_dict)
# --> 136 write_production(
#     137     file_dir=f"{path}/{system}/{system}_pull",
#     138     sim_dir=f"{path}/{system}/umbrella_production_{input_production['steps']}",
#     139     p1=p1,
#     140     p2=p2,
#     141     xmin=xmin,
#     142     xmax=xmax,
#     143     all_forces=all_forces,
#     144     n_gpus=n_gpus,
#     145     input_json_dict=input_production,
#     146     run_file=run_file
#     147 )
#     148 return None
#
# File /scratch/matthew/melting_sims/umbrella/gen_umbrella/production_files.py:125, in write_production(file_dir, sim_dir, p1, p2, xmin, xmax, all_forces, steps_per_window, n_gpus, input_json_dict, run_file, restart_from_last_conf)
#     122 traj = os.path.join(file_dir, 'trajectory.dat')
#     124 # Create umbrella window dirs and separate the pulling confs into umbrella windows
# --> 125 n_confs = sep_conf(os.path.join(file_dir, 'last_conf.dat'), traj, sim_dir)
#     126 x_range = np.linspace(xmin, xmax, (n_confs + 1))[1:]
#     128 #Get the optimal number of windows for each gpu to run
#
# File /scratch/matthew/melting_sims/umbrella/gen_umbrella/production_files.py:21, in sep_conf(last_conf, traj, sim_dir)
#      19     os.mkdir(sim_dir)
#      20 # get number of lines in a singe oxDNA configuration
# ---> 21 num_lines = sum(1 for line in open(last_conf))
#      22 with open(traj, 'r') as f:
#      23     # read trajectory file
#      24     file = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: '//scratch/matthew/melting_sims/umbrella/sim_macros/1p_systems/1p_k10_max7/1p_k10_max7_pull/last_conf.dat'
